# %%
import numpy as np
import pandas as pd
import random
from random import randrange
from random import choice

# %%
data_path = 'Maple_Oak_data.txt'
vector_path = 'Maple_Oak_test.txt'

# %%
def import_data(filename):
    DataSet = list()
    import_data = open(filename, 'r').read().split('\n')
    for i in range(len(import_data)):
        data_row = import_data[i].split(',')
        DataSet.append(data_row[0:])
    return DataSet

# %%
dataset = import_data(data_path)
print(dataset)
vector = import_data(vector_path)
print(vector)
# Out:
# [['Acer Campestre', '0.003906', '0.003906', '0.027344', '0.033203', '0.007812', '0.017578', '0.023438', '0.005859', '0', '0.015625', '0.015625', '0.015625', '0.025391', '0', '0.015625', '0', '0.025391', '0.027344', '0.033203', '0.009766', '0.025391', '0.001953', '0', '0.003906', '0.001953', '0.044922', '0', '0.03125', '0.033203', '0.015625', '0.003906', '0', '0.013672', '0.001953', '0.015625', '0.015625', '0.017578', '0.033203', '0.015625', '0.003906', '0.003906', '0.03125', '0.035156', '0.015625', '0.044922', '0.007812', '0.029297', '0.037109', '0', '0.027344', '0.005859', '0.001953', '0.041016', '0', '0.011719', '0', '0.005859', '0.035156', '0.027344', '0.033203', '0.001953', '0', '0.017578', '0'], ['Acer Campestre', '0.005859', '0.013672', '0.027344', '0.025391', '0.013672', '0.029297', '0.019531', '0', '0.001953', '0.021484', '0.007812', '0.003906', '0.013672', '0.003906', '0.009766', '0', '0.044922', '0.011719', '0.007812', '0.03125', '0.017578', '0.001953', '0', '0.001953', '0.
# ...

# %%
def str_column_to_float(dataset, column):
    for row in dataset:
        row[column] = float(row[column])

# %%
def dataset_to_float(filename):
    dataset = import_data(filename)
    FloatedData = dataset
    for i in range(1,len(FloatedData[0])):
        str_column_to_float(FloatedData, i)
    return FloatedData

# %%
dataset_to_float(vector_path)
dataset_to_float(data_path)

# %%
def dataset_to_panda(filename):
    NewDataSet = dataset_to_float(filename)
    Lables = [lable[0] for lable in NewDataSet]
    Columns = ['Name']+[i for i in range(1,len(NewDataSet[0]))]
    DataFrame = pd.DataFrame(data=NewDataSet, columns=Columns)
    return DataFrame

# %%
dataset_to_panda(vector_path)
# Out:
#                  Name         1         2         3         4         5  \
# 0      Acer Rufinerve  0.001953  0.001953  0.017578  0.023438  0.058594
# 1      Acer Rufinerve  0.003906  0.000000  0.011719  0.013672  0.062500
# 2      Acer Rufinerve  0.000000  0.000000  0.007812  0.013672  0.058594
# 3      Acer Rufinerve  0.000000  0.000000  0.021484  0.013672  0.070312
# 4      Acer Rufinerve  0.001953  0.000000  0.009766  0.009766  0.060547
# 5    Acer Saccharinum  0.000000  0.000000  0.007812  0.031250  0.031250
# 6    Acer Saccharinum  0.000000  0.000000  0.011719  0.015625  0.033203
# 7    Acer Saccharinum  0.000000  0.000000  0.025391  0.015625  0.031250
# 8    Acer Saccharinum  0.000000  0.000000  0.019531  0.023438  0.035156
# 9    Acer Saccharinum  0.000000  0.000000  0.021484  0.025391  0.029297
# 10   Acer Saccharinum  0.000000  0.000000  0.031250  0.027344  0.037109
# 11  Quercus Agrifolia  0.005859  0.033203  0.072266  0.015625  0.001953
# ...

# %%
dataset_to_panda(data_path)
# Out:
#                   Name         1         2         3         4         5  \
# 0       Acer Campestre  0.003906  0.003906  0.027344  0.033203  0.007812
# 1       Acer Campestre  0.005859  0.013672  0.027344  0.025391  0.013672
# 2       Acer Campestre  0.011719  0.001953  0.027344  0.044922  0.017578
# 3       Acer Campestre  0.013672  0.011719  0.037109  0.017578  0.011719
# 4       Acer Campestre  0.007812  0.009766  0.027344  0.025391  0.001953
# ..                 ...       ...       ...       ...       ...       ...
# 747  Quercus Vulcanica  0.003906  0.009766  0.007812  0.029297  0.017578
# 748  Quercus Vulcanica  0.005859  0.003906  0.001953  0.017578  0.015625
# 749  Quercus Vulcanica  0.001953  0.001953  0.003906  0.003906  0.015625
# 750  Quercus Vulcanica  0.000000  0.000000  0.011719  0.048828  0.015625
# 751  Quercus Vulcanica  0.001953  0.005859  0.005859  0.023438  0.009766
#
#             6         7         8         9  ...        55        56  \
# ...

# %%
def distance(row1, row2):
	distance = 0.0
	for i in range(len(row1)):
		distance += (row1[i] - row2[i])**2
	return np.sqrt(distance)

# %%
def get_neighbours(train, test_row, num_neighbours):
    distances = list()
    neighbours = list()
    for train_row in train:
        dist = distance(test_row, train_row)
        #print()
        #print()
        #print()
        #print('trainrow',train_row)
        #print()
        #print()
        #print()
        #print('dist',dist)
        distances.append((train_row, dist))
    #distances.sort(key=lambda tup: tup[1])
    return dist #ances



    
#if (Acer>Quercus):
#    print('Należy do klasy Acer') 
#else:
#    print('Należy do klasy Quercus')

# %%
num_neighbours  = 1

# %%
dataset = import_data(data_path)
print(dataset)
print()
print()
print()
vector = import_data(vector_path)
print(vector)
# Out:
# [['Acer Campestre', '0.003906', '0.003906', '0.027344', '0.033203', '0.007812', '0.017578', '0.023438', '0.005859', '0', '0.015625', '0.015625', '0.015625', '0.025391', '0', '0.015625', '0', '0.025391', '0.027344', '0.033203', '0.009766', '0.025391', '0.001953', '0', '0.003906', '0.001953', '0.044922', '0', '0.03125', '0.033203', '0.015625', '0.003906', '0', '0.013672', '0.001953', '0.015625', '0.015625', '0.017578', '0.033203', '0.015625', '0.003906', '0.003906', '0.03125', '0.035156', '0.015625', '0.044922', '0.007812', '0.029297', '0.037109', '0', '0.027344', '0.005859', '0.001953', '0.041016', '0', '0.011719', '0', '0.005859', '0.035156', '0.027344', '0.033203', '0.001953', '0', '0.017578', '0'], ['Acer Campestre', '0.005859', '0.013672', '0.027344', '0.025391', '0.013672', '0.029297', '0.019531', '0', '0.001953', '0.021484', '0.007812', '0.003906', '0.013672', '0.003906', '0.009766', '0', '0.044922', '0.011719', '0.007812', '0.03125', '0.017578', '0.001953', '0', '0.001953', '0.
# ...

# %%
removed_vector = [ sublist.pop(0) for sublist in vector ]
print(vector)
print()
print()
print()
print()
print(removed_vector)
# Out:
# [['0.001953', '0.001953', '0.017578', '0.023438', '0.058594', '0', '0.005859', '0', '0.013672', '0.003906', '0', '0.021484', '0.001953', '0.003906', '0.039062', '0', '0.003906', '0.005859', '0.003906', '0.007812', '0.037109', '0.005859', '0', '0.003906', '0.015625', '0.021484', '0.009766', '0.052734', '0.007812', '0.027344', '0.044922', '0.052734', '0.003906', '0', '0', '0', '0.001953', '0.048828', '0.054688', '0.013672', '0.035156', '0.003906', '0.009766', '0.052734', '0.003906', '0.017578', '0.046875', '0.042969', '0.03125', '0.007812', '0.001953', '0.005859', '0.041016', '0.027344', '0.007812', '0.021484', '0', '0', '0.003906', '0.021484', '0', '0', '0', '0'], ['0.003906', '0', '0.011719', '0.013672', '0.0625', '0', '0.013672', '0.005859', '0.011719', '0.009766', '0', '0.033203', '0', '0.009766', '0.035156', '0', '0.003906', '0', '0.005859', '0.003906', '0.03125', '0.009766', '0', '0.003906', '0.011719', '0.015625', '0.005859', '0.037109', '0', '0.039062', '0.044922', '0.037109', 
# ...

# %%
removed_data = [ sublist.pop(0) for sublist in dataset ]
print(dataset)
print()
print()
print()
print()
print(removed_data)
# Out:
# [['0.003906', '0.003906', '0.027344', '0.033203', '0.007812', '0.017578', '0.023438', '0.005859', '0', '0.015625', '0.015625', '0.015625', '0.025391', '0', '0.015625', '0', '0.025391', '0.027344', '0.033203', '0.009766', '0.025391', '0.001953', '0', '0.003906', '0.001953', '0.044922', '0', '0.03125', '0.033203', '0.015625', '0.003906', '0', '0.013672', '0.001953', '0.015625', '0.015625', '0.017578', '0.033203', '0.015625', '0.003906', '0.003906', '0.03125', '0.035156', '0.015625', '0.044922', '0.007812', '0.029297', '0.037109', '0', '0.027344', '0.005859', '0.001953', '0.041016', '0', '0.011719', '0', '0.005859', '0.035156', '0.027344', '0.033203', '0.001953', '0', '0.017578', '0'], ['0.005859', '0.013672', '0.027344', '0.025391', '0.013672', '0.029297', '0.019531', '0', '0.001953', '0.021484', '0.007812', '0.003906', '0.013672', '0.003906', '0.009766', '0', '0.044922', '0.011719', '0.007812', '0.03125', '0.017578', '0.001953', '0', '0.001953', '0.001953', '0.037109', '0', '0.029297'
# ...

# %%
print(dataset)
print()
print(vector)
print()
print(num_neighbours)
# Out:
# [['0.003906', '0.003906', '0.027344', '0.033203', '0.007812', '0.017578', '0.023438', '0.005859', '0', '0.015625', '0.015625', '0.015625', '0.025391', '0', '0.015625', '0', '0.025391', '0.027344', '0.033203', '0.009766', '0.025391', '0.001953', '0', '0.003906', '0.001953', '0.044922', '0', '0.03125', '0.033203', '0.015625', '0.003906', '0', '0.013672', '0.001953', '0.015625', '0.015625', '0.017578', '0.033203', '0.015625', '0.003906', '0.003906', '0.03125', '0.035156', '0.015625', '0.044922', '0.007812', '0.029297', '0.037109', '0', '0.027344', '0.005859', '0.001953', '0.041016', '0', '0.011719', '0', '0.005859', '0.035156', '0.027344', '0.033203', '0.001953', '0', '0.017578', '0'], ['0.005859', '0.013672', '0.027344', '0.025391', '0.013672', '0.029297', '0.019531', '0', '0.001953', '0.021484', '0.007812', '0.003906', '0.013672', '0.003906', '0.009766', '0', '0.044922', '0.011719', '0.007812', '0.03125', '0.017578', '0.001953', '0', '0.001953', '0.001953', '0.037109', '0', '0.029297'
# ...

# %%
for i in reversed(range(1,len(dataset[0]))):
	str_column_to_float(dataset, i)

# %%
for i in reversed(range(1,len(vector[0]))):
	str_column_to_float(vector, i)

# %%
adataset = np.array(dataset)
adataset = adataset.astype(float)
avector = np.array(vector)
avector = avector.astype(float)

# %%
avector
# Out:
# array([[0.001953, 0.001953, 0.017578, ..., 0.      , 0.      , 0.      ],
#        [0.003906, 0.      , 0.011719, ..., 0.007812, 0.003906, 0.001953],
#        [0.      , 0.      , 0.007812, ..., 0.005859, 0.      , 0.007812],
#        ...,
#        [0.017578, 0.029297, 0.03125 , ..., 0.      , 0.041016, 0.      ],
#        [0.013672, 0.03125 , 0.042969, ..., 0.      , 0.03125 , 0.      ],
#        [0.017578, 0.029297, 0.048828, ..., 0.      , 0.037109, 0.      ]])

# %%
def distance(row1, row2):
	distance = 0.0
	for i in range(len(row1)):
		distance += (row1[i] - row2[i])**2
	return np.sqrt(distance)

# %%
def get_neighbours(train, test_row, num_neighbours):
    distances = list()
    neighbours = list()
    distlist = list()
    for train_row in train:
        dist = distance(test_row, train_row)
        #print()
        #print()
        #print()
        #print('trainrow',train_row)
        #print()
        #print()
        #print()
        #print('dist',dist)
        #distances.append((train_row, dist))
        distlist.append(dist)
    #distances.sort(key=lambda tup: tup[1])
    return dist #ances



    
#if (Acer>Quercus):
#    print('Należy do klasy Acer') 
#else:
#    print('Należy do klasy Quercus')

# %%
ary = get_neighbours(adataset, avector, 1)
print(ary)
# Out:
# [0.04975761 0.06070464 0.12049428 0.06234828 0.13997251 0.04994873
#  0.04679348 0.04642623 0.09125522 0.05524364 0.06259194 0.0633191
#  0.11328134 0.11700835 0.07931226 0.05196997 0.0403131  0.04166252
#  0.06894334 0.04045443 0.11739897 0.06858245 0.04979593 0.0640082
#  0.0841209  0.04711885 0.11853099 0.10225503 0.04626104 0.06620513
#  0.11946021 0.14756122 0.04823967 0.05040517 0.0421176  0.05070653
#  0.05017683 0.14240421 0.09049999 0.04910223 0.12128231 0.04906274
#  0.08186889 0.0718686  0.03627865 0.0747823  0.14226991 0.13074305
#  0.17221738 0.10307267 0.05924128 0.08890514 0.07247673 0.1164529
#  0.04354238 0.05943442 0.03959684 0.04380479 0.08026871 0.06173298
#  0.05029154 0.08999238 0.09618019 0.12187873]

# %%
Lables = [lable[0] for lable in ary]
Columns = ['Name']+[i for i in range(1,len(ary[0]))]
AryFrame = pd.DataFrame(data=ary, columns=Columns)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-69-a4d9e0c364ab> in <module>
# ----> 1 Lables = [lable[0] for lable in ary]
#       2 Columns = ['Name']+[i for i in range(1,len(ary[0]))]
#       3 AryFrame = pd.DataFrame(data=ary, columns=Columns)
#
# <ipython-input-69-a4d9e0c364ab> in <listcomp>(.0)
# ----> 1 Lables = [lable[0] for lable in ary]
#       2 Columns = ['Name']+[i for i in range(1,len(ary[0]))]
#       3 AryFrame = pd.DataFrame(data=ary, columns=Columns)
#
# IndexError: invalid index to scalar variable.

# %%
AryFrame
# Out:
#                                                   Name  \
# 0    [0.003906, 0.003906, 0.027344, 0.033203, 0.007...
# 1    [0.005859, 0.013672, 0.027344, 0.025391, 0.013...
# 2    [0.011719, 0.001953, 0.027344, 0.044922, 0.017...
# 3    [0.013672, 0.011719, 0.037109, 0.017578, 0.011...
# 4    [0.007812, 0.009766, 0.027344, 0.025391, 0.001...
# ..                                                 ...
# 747  [0.003906, 0.009766, 0.007812, 0.029297, 0.017...
# 748  [0.005859, 0.003906, 0.001953, 0.017578, 0.015...
# 749  [0.001953, 0.001953, 0.003906, 0.003906, 0.015...
# 750  [0.0, 0.0, 0.011719, 0.048828, 0.015625, 0.0, ...
# 751  [0.001953, 0.005859, 0.005859, 0.023438, 0.009...
#
#                                                      1
# 0    [0.0666931559607131, 0.07672088369537984, 0.11...
# 1    [0.06585846679053499, 0.08014970734194854, 0.1...
# 2    [0.08393938621410095, 0.09346525246849761, 0.1...
# 3    [0.11163650054529656, 0.11880421049356794, 0.1...
# ...
